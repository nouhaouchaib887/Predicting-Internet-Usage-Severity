# %%
import pandas as pd
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns
import numpy as np
from sklearn.utils import resample
import os

# %%
# Function to convert nanoseconds to HH:MM:SS
def nanoseconds_to_time(nanoseconds):
    hours = nanoseconds // (60 * 60 * 10**9)
    remaining_ns = nanoseconds % (60 * 60 * 10**9)
    minutes = remaining_ns // (60 * 10**9)
    remaining_ns %= (60 * 10**9)
    seconds = remaining_ns // (10**9)
    return f"{int(hours):02}:{int(minutes):02}:{int(seconds):02}"

# %%
#Define a function to segment the day
def segment_day(hour):
    if 5 <= hour < 12:
        return 'morning'
    elif 12 <= hour < 17:
        return 'afternoon'
    elif 17 <= hour < 21:
        return 'evening'
    else:
        return 'night'

# %%
def preprocess_data(df):
    df['time_of_day_hms'] = df['time_of_day'].apply(nanoseconds_to_time)
    df['time_of_day_hms'] = pd.to_datetime(df['time_of_day_hms'], format='%H:%M:%S')
    df['day_segment'] = df['time_of_day_hms'].dt.hour.apply(segment_day)
    return df

# %%
def compute_global_stats(df_id):
    """
    This function computes global statistics (mean, std, mdian) for columns.
    """

    # Filter rows where the watch is worn
    df_filtered = df_id[df_id['non-wear_flag'] == 0].copy()

    # Calculate statistics for the 'enmo' column
    accNorm_mean = df_filtered['enmo'].mean()
    accNorm_std = df_filtered['enmo'].std()
    accNorm_median = df_filtered['enmo'].median()

    # Calculate statistics for the 'anglez' column
    anglez_mean = df_filtered['anglez'].mean()
    anglez_std = df_filtered['anglez'].std()
    anglez_median = df_filtered['anglez'].median()
    # Calculate statistics for the 'anglez' column
    light_mean = df_filtered['light'].mean()
    light_std = df_filtered['light'].std()
    light_median = df_filtered['light'].median()
    # Return a dictionary containing the computed statistics
    stats_dict = {
        'accNorm_mean': accNorm_mean,
        'accNorm_std': accNorm_std,
        'accNorm_median': accNorm_median,
        'anglez_mean': anglez_mean,
        'anglez_std': anglez_std,
        'anglez_median': anglez_median,
        'light_mean': light_mean,
        'light_std': light_std,
        'light_median': light_median,
    }

    return stats_dict

# %%
def compute_segmented_stats(df):
    """
    This function calculates segmented statistics (mean, std, median)
    for the variables 'light', 'enmo', and 'anglez', based on four segments of the day:
    morning, afternoon, evening, and night.
    """
    df_filtered = df[df["non-wear_flag"] == 0 ].copy()
    grouped = df_filtered.groupby('day_segment')

    # Compute the statistics for each segment and variable
    stats_dict = {}
    variables = ['light', 'enmo', 'anglez']
    for seg in grouped.groups:
        subset = grouped.get_group(seg)
        for var in variables:
            stats_dict[f"{seg}_{var}_mean"] = subset[var].mean()
            stats_dict[f"{seg}_{var}_std"] = subset[var].std()
            stats_dict[f"{seg}_{var}_median"] = subset[var].median()

    #Return a dictionary of all segmented statistics
    return stats_dict

# %%
def find_successive_sequences_with_stats_per_day(df: pd.DataFrame) -> pd.DataFrame:
    """
    For each day (relative_date_PCIAT), detect successive sequences
    that satisfy the condition (e.g., X and Y < 0.5 in absolute value,
    non-wear_flag == 0, etc.), and compute  statistics 
    5on columns.
    
    Returns a DataFrame listing, for each day and each sequence:
    - relative_date_PCIAT: the day in question
    - start_index: the index of the first row in the sequence
    - length: the number of rows in the sequence
    - light, anglez
    - date_start: the date corresponding to the start of the sequence
    """

    # store the results for each day 
    all_days_results = []

    # Group the DataFrame by 'relative_date_PCIAT'y.
    for day, group in df.groupby("relative_date_PCIAT"):

        # Define the condition for this group.
        condition = (
            (group["X"].abs() < 0.5) #inactivity
            & (group["Y"].abs() < 0.5)
            & (group["non-wear_flag"] == 0)
        )

        # Detect the beginning of a sequence when False -> True
        # fill_value=False handles the first row shift
        transitions = ((condition != condition.shift(fill_value=False)) & condition).cumsum()

        # Keep only rows satisfying the condition
        group_temp = group[condition].copy()
        group_temp["bloc_id"] = transitions[condition]

        if group_temp.empty:
            # If no rows satisfy the condition for this day, move on
            continue

        # Calculate statistics on the sub-group
        res = (
            group_temp
            .groupby("bloc_id", as_index=False)
            .agg(
                start_index=("step", "min"),
                length=("step", "size"),
                light=("light", "mean"),
                anglez=("anglez", "mean"),
                date_start=("time_of_day_hms", "first")  # the date at the start of the sequence
            )
        )

        # Add the 'relative_date_PCIAT' column to indicate the day
        res["relative_date_PCIAT"] = day

        # Append these results to our master list
        all_days_results.append(res)

    # Concatenate the results from all days
    if not all_days_results:
        return pd.DataFrame()  # returns an empty DataFrame if there are no sequences at all

    final_result = pd.concat(all_days_results, ignore_index=True)

    # (Optional) sort by relative_date_PCIAT and start_index
    final_result.sort_values(["relative_date_PCIAT", "start_index"], inplace=True)
    final_result.reset_index(drop=True, inplace=True)

    return final_result

# %%
def compute_daily_inactivity_stats(sequences: pd.DataFrame, data: pd.DataFrame ) -> pd.DataFrame:
    """
    Computes daily inactivity statistics from a DataFrame of inactivity sequences, while also
    using a second DataFrame to calculate the actual daily wear time. This allows for
    computing 'pct_inactive_day' as a percentage of the total time that the watch was worn.

    Parameters
    ----------
    sequences : pd.DataFrame
        A DataFrame containing inactivity sequences, typically with one row per sequence.
        Required columns include:
          - 'relative_date_PCIAT' (identifier for each day)
          - 'length' (number of consecutive samples in the inactivity sequence, each sample = 5s)
          - 'light' (average light during the sequence)
          - 'anglez' (average angleZ during the sequence)
          - 'non_wear_flag' (0 if the watch is worn, 1 if not worn)
          (Though 'non_wear_flag' may not be strictly required if it's also present in 'data'.)

    data : pd.DataFrame
        A DataFrame containing the more complete set of daily samples (including wear/non-wear),
        from which we derive the total daily wear time. Must include:
          - 'relative_date_PCIAT'
          - 'non_wear_flag'
        so that we can count how many samples in a given day have 'non_wear_flag == 0'.

    Returns:
    A DataFrame (stats_df) grouped by 'relative_date_PCIAT' with the following columns:
      * num_inactive_sequences        (count of inactivity sequences)
      * mean_light_in_sequences
      * max_light_in_sequences
      * std_light_in_sequences
      * median_light_in_sequences
      * mean_anglez_in_sequences
      * max_anglez_in_sequences
      * std_anglez_in_sequences
      * median_anglez_in_sequences
      * total_inactive_duration_min   (total_length converted to minutes)
      * daily_wear_time_min           (actual wearing time that day, in minutes)
      * pct_inactive_day              (percentage of inactivity relative to daily wear time)
    """

    # --------------------------------------------------------------------------
    # 1) First, compute inactivity statistics
    # --------------------------------------------------------------------------
    stats_df = (
        sequences.groupby('relative_date_PCIAT')
        .agg(
            num_inactive_sequences=('length', 'count'),         # Number of inactivity sequences
            total_length=('length', 'sum'),                     # Total sum of 'length'
            
            # Light statistics
            mean_light_in_sequences=('light', 'mean'),
            max_light_in_sequences=('light', 'max'),
            std_light_in_sequences=('light', 'std'),
            median_light_in_sequences=('light', 'median'),
            
            # AngleZ statistics
            mean_anglez_in_sequences=('anglez', 'mean'),
            max_anglez_in_sequences=('anglez', 'max'),
            std_anglez_in_sequences=('anglez', 'std'),
            median_anglez_in_sequences=('anglez', 'median')
        )
        .reset_index()
    )

    # Convert total_length into minutes: total_length * 5 seconds / 60
    stats_df['total_inactive_duration_min'] = stats_df['total_length'] * 5.0 / 60.0

    # --------------------------------------------------------------------------
    # 2) Compute actual daily wear time in minutes (based on non_wear_flag == 0)
    # --------------------------------------------------------------------------
    wear_time_df = (
        data.groupby('relative_date_PCIAT')
        .agg(num_wear_samples=('non-wear_flag', lambda col: (col == 0).sum()))
        .reset_index()
    )
    # Convert samples to minutes (each sample = 5 seconds)
    wear_time_df['daily_wear_time_min'] = wear_time_df['num_wear_samples'] * 5.0 / 60.0

    # Merge wear time into stats_df
    stats_df = stats_df.merge(
        wear_time_df[['relative_date_PCIAT', 'daily_wear_time_min']],
        on='relative_date_PCIAT',
        how='left'
    )

    # --------------------------------------------------------------------------
    # 3) Compute pct_inactive_day = total_inactive_duration_min / daily_wear_time_min * 100
    # --------------------------------------------------------------------------
    def compute_inactive_pct(row):
        wear_time = row['daily_wear_time_min']
        inactive_time = row['total_inactive_duration_min']
        if wear_time > 0:
            return (inactive_time / wear_time) * 100.0
        else:
            return 0.0  # If the watch was never worn that day

    stats_df['pct_inactive_day'] = stats_df.apply(compute_inactive_pct, axis=1)

    # --------------------------------------------------------------------------
    # 4) Drop the 'total_length' column from the final DataFrame
    # --------------------------------------------------------------------------
    stats_df.drop(columns=['total_length'], inplace=True, errors='ignore')

    return stats_df

# %%
def compute_global_inactivity_stats(daily_stats: pd.DataFrame) -> dict:
    """
    Aggregates daily statistics across all days into global-level features, 
    returning them in a dictionary instead of a DataFrame.

    Parameters
    ----------
    daily_stats : pd.DataFrame
        A DataFrame that typically contains one row per day, including columns such as:
          - num_inactive_sequences
          - total_length
          - mean_light_in_sequences
          - max_light_in_sequences
          - std_light_in_sequences
          - median_light_in_sequences
          - mean_anglez_in_sequences
          - ...
          - total_inactive_duration_min
          - daily_wear_time_min
          - pct_inactive_day
        and any other daily metrics.

    Returns
    -------
    dict
        A dictionary of aggregated statistics where each numeric column
        from the input is mapped to mean, std, min, and max. The keys in 
        the dictionary follow this naming pattern:
        <original_column>_mean, <original_column>_std, etc.

    Notes
    -----
    - If you have multiple IDs (e.g., multiple participants/users), you could 
      add a groupby on that ID column and apply this aggregation per user.
    - You can customize which statistics are computed or how they're named.
    """

    # Identify all numeric columns in daily_stats
    numeric_cols = daily_stats.select_dtypes(include=['number']).columns
    
    # Exclude 'relative_date_PCIAT' if it happens to be in numeric_cols
    numeric_cols = [col for col in numeric_cols if col != 'relative_date_PCIAT']

    # Prepare a dictionary to hold aggregated results
    aggregated_result = {}

    for col in numeric_cols:
        aggregated_result[f"{col}_mean"] = daily_stats[col].mean()
        aggregated_result[f"{col}_std"] = daily_stats[col].std()
        aggregated_result[f"{col}_min"] = daily_stats[col].min()
        aggregated_result[f"{col}_max"] = daily_stats[col].max()

    return aggregated_result

# %%
def process_ids_and_extract_features(data: pd.DataFrame) -> pd.DataFrame:
    """
    For each ID in the input DataFrame 'data', this function:
      1. Checks if the folder 'id={id}' exists.
      2. If it does, reads the file 'part-0.parquet' from that folder.
      3. Applies the following chain of functions in order:
         - preprocess_data(df) -> returns a processed DataFrame.
         - compute_global_stats(df) -> returns a dict of global stats.
         - compute_segmented_stats(df) -> returns a dict of segmented stats.
         - find_successive_sequences_with_stats_per_day(df) -> returns a sequences DataFrame.
         - compute_daily_inactivity_stats(sequences_df) -> returns a daily-stats DataFrame.
         - compute_global_inactivity_stats(daily_stats_df) -> returns a dict of global inactivity stats.
      4. Merges all the dictionaries of results (global stats, segmented stats, global inactivity stats)
         into a single dictionary.
      5. Appends those columns (key/value pairs) into the 'data' DataFrame for that specific ID.

    Parameters
    ----------
    data : pd.DataFrame
        A DataFrame containing at least one column 'id' which uniquely identifies each entity.

    Returns
    -------
    pd.DataFrame
        The same 'data' DataFrame with additional columns containing the computed features.
    """

    for i, row in data.iterrows():
        current_id = row['id']
        folder = f"Downloads/series_train.parquet/id={current_id}"
        parquet_file = os.path.join(folder, "part-0.parquet")

        # Check if the folder/file exists
        if not os.path.exists(parquet_file):
            print(f"Folder or file not found for ID={current_id}. Skipping.")
            continue

        # Read the Parquet file
        try:
            df_parquet = pd.read_parquet(parquet_file)
        except Exception as e:
            print(f"Error reading parquet file for ID={current_id}: {e}")
            continue

        # ---------------------------------------------------------------------
        # 1) Preprocess the data
        # ---------------------------------------------------------------------
        df_processed = preprocess_data(df_parquet)

        # ---------------------------------------------------------------------
        # 2) Compute global stats (returns a dict)
        # ---------------------------------------------------------------------
        global_stats_dict = compute_global_stats(df_processed)

        # ---------------------------------------------------------------------
        # 3) Compute segmented stats (returns a dict)
        # ---------------------------------------------------------------------
        segmented_stats_dict = compute_segmented_stats(df_processed)

        # ---------------------------------------------------------------------
        # 4) Find successive inactivity sequences per day (returns a DataFrame)
        # ---------------------------------------------------------------------
        sequences_df = find_successive_sequences_with_stats_per_day(df_processed)

        # ---------------------------------------------------------------------
        # 5) Compute daily inactivity stats on the sequences (returns a DataFrame)
        # ---------------------------------------------------------------------
        daily_inactivity_df = compute_daily_inactivity_stats(sequences_df, df_processed )

        # ---------------------------------------------------------------------
        # 6) Compute global inactivity stats (returns a dict)
        # ---------------------------------------------------------------------
        global_inactivity_dict = compute_global_inactivity_stats(daily_inactivity_df)

        # ---------------------------------------------------------------------
        # Merge all dict results into one dictionary
        # ---------------------------------------------------------------------
        combined_features = {
            **global_stats_dict,
            **segmented_stats_dict,
            **global_inactivity_dict
        }

        # ---------------------------------------------------------------------
        # Append these new columns into 'data' for the current ID
        # ---------------------------------------------------------------------
        for col_name, col_value in combined_features.items():
            data.at[i, col_name] = col_value

    # Return the updated DataFrame
    return data

# %%
data = pd.read_csv("train (1).csv")

# %%
data
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# 0         Winter             51.0            Fall     16.877316
# 1            NaN              NaN            Fall     14.035590
# 2           Fall             71.0            Fall     16.648696
# 3           Fall             71.0          Summer     18.292347
# 4         Summer              NaN             NaN           NaN
# ...          ...              ...             ...           ...
# 3955      Spring             60.0            Fall     16.362460
# 3956         NaN              NaN          Spring     18.764678
# 3957      Spring             68.0          Winter     21.441500
# 3958      Spring             70.0          Winter     12.235895
# 3959         NaN              NaN          Winter           NaN
#
#       Physical-Height  Physical-Weight  ...  PCIAT-PCIAT_18  PCIAT-PCIAT_19  \
# 0                46.0             50.8  ...             4.0             2.0
# 1                48.0             46.0  ...             0.0             0.0
# 2                56.5             75.6  ...             2.0             1.0
# 3                56.0             81.6  ...             3.0             4.0
# 4                 NaN              NaN  ...             NaN             NaN
# ...               ...              ...  ...             ...             ...
# 3955             59.5             82.4  ...             1.0             1.0
# 3956             53.5             76.4  ...             NaN             NaN
# 3957             60.0            109.8  ...             1.0             0.0
# 3958             70.7             87.0  ...             1.0             1.0
# 3959              NaN              NaN  ...             NaN             NaN
#
#       PCIAT-PCIAT_20  PCIAT-PCIAT_Total SDS-Season  SDS-SDS_Total_Raw  \
# 0                4.0               55.0        NaN                NaN
# 1                0.0                0.0       Fall               46.0
# 2                1.0               28.0       Fall               38.0
# 3                1.0               44.0     Summer               31.0
# 4                NaN                NaN        NaN                NaN
# ...              ...                ...        ...                ...
# 3955             0.0               32.0     Winter               35.0
# 3956             NaN                NaN        NaN                NaN
# 3957             1.0               31.0     Winter               56.0
# 3958             1.0               19.0     Spring               33.0
# 3959             NaN                NaN        NaN                NaN
#
#       SDS-SDS_Total_T  PreInt_EduHx-Season  \
# 0                 NaN                 Fall
# 1                64.0               Summer
# 2                54.0               Summer
# 3                45.0               Winter
# 4                 NaN                  NaN
# ...               ...                  ...
# 3955             50.0                 Fall
# 3956              NaN               Winter
# 3957             77.0                 Fall
# 3958             47.0               Spring
# 3959              NaN               Spring
#
#      PreInt_EduHx-computerinternet_hoursday  sii
# 0                                       3.0  2.0
# 1                                       0.0  0.0
# 2                                       2.0  0.0
# 3                                       0.0  1.0
# 4                                       NaN  NaN
# ...                                     ...  ...
# 3955                                    1.0  1.0
# 3956                                    0.0  NaN
# 3957                                    0.0  1.0
# 3958                                    1.0  0.0
# 3959                                    1.0  NaN
#
# [3960 rows x 82 columns]

# %%
final_data = process_ids_and_extract_features(data)
# Out:
# Folder or file not found for ID=00008ff9. Skipping.
# Folder or file not found for ID=000fd460. Skipping.
# Folder or file not found for ID=00105258. Skipping.
# Folder or file not found for ID=0016bb22. Skipping.
# Folder or file not found for ID=0038ba98. Skipping.
# Folder or file not found for ID=0068a485. Skipping.
# Folder or file not found for ID=0069fbed. Skipping.
# Folder or file not found for ID=0083e397. Skipping.
# Folder or file not found for ID=0087dd65. Skipping.
# Folder or file not found for ID=00abe655. Skipping.
# Folder or file not found for ID=00ae59c9. Skipping.
# Folder or file not found for ID=00af6387. Skipping.
# Folder or file not found for ID=00bd4359. Skipping.
# Folder or file not found for ID=00c0cd71. Skipping.
# Folder or file not found for ID=00d56d4b. Skipping.
# Folder or file not found for ID=00d9913d. Skipping.
# Folder or file not found for ID=00e6167c. Skipping.
# Folder or file not found for ID=00ebc35d. Skipping.
# Folder or file not found for ID=00f574e9. Skipping.
# Folder or file not found for ID=01182ce3. Skipping.
# Folder or file not found for ID=011e71c3. Skipping.
# Folder or file not found for ID=014c303e. Skipping.
# Folder or file not found for ID=015ba5b1. Skipping.
# Folder or file not found for ID=0194c251. Skipping.
# Folder or file not found for ID=019c9266. Skipping.
# Folder or file not found for ID=01cae1ef. Skipping.
# Folder or file not found for ID=01d24f60. Skipping.
# Folder or file not found for ID=01dc6dcd. Skipping.
# Folder or file not found for ID=01e9a5c0. Skipping.
# Folder or file not found for ID=01f83da1. Skipping.
# Folder or file not found for ID=02073150. Skipping.
# Folder or file not found for ID=02132c62. Skipping.
# Folder or file not found for ID=0219f64a. Skipping.
# Folder or file not found for ID=021b2020. Skipping.
# Folder or file not found for ID=0232fd98. Skipping.
# Folder or file not found for ID=02347f13. Skipping.
# Folder or file not found for ID=023e1b6a. Skipping.
# Folder or file not found for ID=023eba7b. Skipping.
# Folder or file not found for ID=026102c4. Skipping.
# Folder or file not found for ID=02648a1c. Skipping.
# Folder or file not found for ID=026fcbc3. Skipping.
# Folder or file not found for ID=0274e7f3. Skipping.
# Folder or file not found for ID=02a01f18. Skipping.
# Folder or file not found for ID=02c4cf7f. Skipping.
# Folder or file not found for ID=02dcf62a. Skipping.
# Folder or file not found for ID=02e56a7c. Skipping.
# Folder or file not found for ID=0347462d. Skipping.
# Folder or file not found for ID=034f923b. Skipping.
# Folder or file not found for ID=0357a10e. Skipping.
# Folder or file not found for ID=0380e709. Skipping.
# Folder or file not found for ID=03833cec. Skipping.
# Folder or file not found for ID=0391e587. Skipping.
# Folder or file not found for ID=03a5c2d6. Skipping.
# Folder or file not found for ID=03bf5026. Skipping.
# Folder or file not found for ID=03e83fef. Skipping.
# Folder or file not found for ID=03f1c1c8. Skipping.
# Folder or file not found for ID=040d103f. Skipping.
# Folder or file not found for ID=04189592. Skipping.
# Folder or file not found for ID=04370442. Skipping.
# Folder or file not found for ID=0441d6af. Skipping.
# Folder or file not found for ID=0470efa4. Skipping.
# Folder or file not found for ID=0471236c. Skipping.
# Folder or file not found for ID=0499c3e8. Skipping.
# Folder or file not found for ID=04a1633e. Skipping.
# Folder or file not found for ID=04ad419d. Skipping.
# Folder or file not found for ID=04aeed24. Skipping.
# Folder or file not found for ID=04af8fdd. Skipping.
# Folder or file not found for ID=04b3cc70. Skipping.
# Folder or file not found for ID=04ccb838. Skipping.
# Folder or file not found for ID=04dc7df1. Skipping.
# Folder or file not found for ID=04df895a. Skipping.
# Folder or file not found for ID=0506b9cd. Skipping.
# Folder or file not found for ID=051f73ae. Skipping.
# Folder or file not found for ID=052a1122. Skipping.
# Folder or file not found for ID=053d7d31. Skipping.
# Folder or file not found for ID=056d498e. Skipping.
# Folder or file not found for ID=05777ce1. Skipping.
# Folder or file not found for ID=058990e9. Skipping.
# Folder or file not found for ID=058d2812. Skipping.
# Folder or file not found for ID=0598f669. Skipping.
# Folder or file not found for ID=059e02ab. Skipping.
# Folder or file not found for ID=059fe566. Skipping.
# Folder or file not found for ID=05bc318e. Skipping.
# Folder or file not found for ID=05d3d73a. Skipping.
# Folder or file not found for ID=05dc60ef. Skipping.
# Folder or file not found for ID=05e67680. Skipping.
# Folder or file not found for ID=05ed65f0. Skipping.
# Folder or file not found for ID=05f2d1b5. Skipping.
# Folder or file not found for ID=0610c066. Skipping.
# Folder or file not found for ID=061f2866. Skipping.
# Folder or file not found for ID=0632d98a. Skipping.
# Folder or file not found for ID=063353cc. Skipping.
# Folder or file not found for ID=06472198. Skipping.
# Folder or file not found for ID=065801e3. Skipping.
# Folder or file not found for ID=066343d4. Skipping.
# Folder or file not found for ID=0676ead5. Skipping.
# Folder or file not found for ID=0677d22d. Skipping.
# Folder or file not found for ID=067de065. Skipping.
# Folder or file not found for ID=068f83f2. Skipping.
# Folder or file not found for ID=06b46af3. Skipping.
# Folder or file not found for ID=06c7dcff. Skipping.
# Folder or file not found for ID=06ec8be3. Skipping.
# Folder or file not found for ID=07662280. Skipping.
# Folder or file not found for ID=077ac7a2. Skipping.
# Folder or file not found for ID=07840b8d. Skipping.
# Folder or file not found for ID=07d879cf. Skipping.
# Folder or file not found for ID=08159c5e. Skipping.
# Folder or file not found for ID=083c9b36. Skipping.
# Folder or file not found for ID=0844aee7. Skipping.
# Folder or file not found for ID=086d6e7f. Skipping.
# Folder or file not found for ID=0882b065. Skipping.
# Folder or file not found for ID=0884aca8. Skipping.
# Folder or file not found for ID=08c390b6. Skipping.
# Folder or file not found for ID=08fa44ad. Skipping.
# Folder or file not found for ID=09039272. Skipping.
# Folder or file not found for ID=092494ec. Skipping.
# Folder or file not found for ID=0924b815. Skipping.
# Folder or file not found for ID=0928b047. Skipping.
# Folder or file not found for ID=092c29b9. Skipping.
# Folder or file not found for ID=094f8386. Skipping.
# Folder or file not found for ID=09614060. Skipping.
# Folder or file not found for ID=096bf063. Skipping.
# Folder or file not found for ID=096e6074. Skipping.
# Folder or file not found for ID=09817490. Skipping.
# Folder or file not found for ID=098b5836. Skipping.
# Folder or file not found for ID=098d3c32. Skipping.
# Folder or file not found for ID=09d3bd98. Skipping.
# Folder or file not found for ID=09d80057. Skipping.
# Folder or file not found for ID=09e4ac05. Skipping.
# Folder or file not found for ID=09eeaba6. Skipping.
# Folder or file not found for ID=09eeec14. Skipping.
# Folder or file not found for ID=09f44fd2. Skipping.
# Folder or file not found for ID=09f84bae. Skipping.
# Folder or file not found for ID=0a1afc11. Skipping.
# Folder or file not found for ID=0a24c842. Skipping.
# Folder or file not found for ID=0a4b1425. Skipping.
# Folder or file not found for ID=0a540797. Skipping.
# Folder or file not found for ID=0a5f1214. Skipping.
# Folder or file not found for ID=0a775819. Skipping.
# Folder or file not found for ID=0a822c93. Skipping.
# Folder or file not found for ID=0a88a5d5. Skipping.
# Folder or file not found for ID=0a9159f8. Skipping.
# Folder or file not found for ID=0a96d897. Skipping.
# Folder or file not found for ID=0a995f99. Skipping.
# Folder or file not found for ID=0aa90ce7. Skipping.
# Folder or file not found for ID=0aaf08ec. Skipping.
# Folder or file not found for ID=0ac521c8. Skipping.
# Folder or file not found for ID=0ac5e12f. Skipping.
# Folder or file not found for ID=0acac70c. Skipping.
# Folder or file not found for ID=0acda781. Skipping.
# Folder or file not found for ID=0adf511d. Skipping.
# Folder or file not found for ID=0af81037. Skipping.
# Folder or file not found for ID=0afb2535. Skipping.
# Folder or file not found for ID=0b4f597e. Skipping.
# Folder or file not found for ID=0b6b07f6. Skipping.
# Folder or file not found for ID=0b74b755. Skipping.
# Folder or file not found for ID=0b7c6100. Skipping.
# Folder or file not found for ID=0b8cba78. Skipping.
# Folder or file not found for ID=0b9fcc42. Skipping.
# Folder or file not found for ID=0ba53e53. Skipping.
# Folder or file not found for ID=0bda0042. Skipping.
# Folder or file not found for ID=0bdace00. Skipping.
# Folder or file not found for ID=0bf4e81b. Skipping.
# Folder or file not found for ID=0c008058. Skipping.
# Folder or file not found for ID=0c0a1576. Skipping.
# Folder or file not found for ID=0c3d248f. Skipping.
# Folder or file not found for ID=0c3d88cb. Skipping.
# Folder or file not found for ID=0c71fc27. Skipping.
# Folder or file not found for ID=0c794cf7. Skipping.
# Folder or file not found for ID=0c83af0f. Skipping.
# Folder or file not found for ID=0c8efce0. Skipping.
# Folder or file not found for ID=0ca08054. Skipping.
# Folder or file not found for ID=0cccc6bc. Skipping.
# Folder or file not found for ID=0cea0da4. Skipping.
# Folder or file not found for ID=0d34aee4. Skipping.
# Folder or file not found for ID=0d394928. Skipping.
# Folder or file not found for ID=0d5e7943. Skipping.
# Folder or file not found for ID=0d74d0ed. Skipping.
# Folder or file not found for ID=0d9bbd88. Skipping.
# Folder or file not found for ID=0db8da5b. Skipping.
# Folder or file not found for ID=0ddab8ff. Skipping.
# Folder or file not found for ID=0de01ae7. Skipping.
# Folder or file not found for ID=0df44f9e. Skipping.
# Folder or file not found for ID=0df4c27d. Skipping.
# Folder or file not found for ID=0df73b79. Skipping.
# Folder or file not found for ID=0dfcdebc. Skipping.
# Folder or file not found for ID=0e1cf9b8. Skipping.
# Folder or file not found for ID=0e1f7fed. Skipping.
# Folder or file not found for ID=0e3ec3fc. Skipping.
# Folder or file not found for ID=0e64e5ef. Skipping.
# Folder or file not found for ID=0e75ad18. Skipping.
# Folder or file not found for ID=0e8a22e1. Skipping.
# Folder or file not found for ID=0e951124. Skipping.
# Folder or file not found for ID=0e9c1be6. Skipping.
# Folder or file not found for ID=0ec52194. Skipping.
# Folder or file not found for ID=0ecdc3e0. Skipping.
# Folder or file not found for ID=0ee70b3e. Skipping.
# Folder or file not found for ID=0ef6e368. Skipping.
# Folder or file not found for ID=0f38e035. Skipping.
# Folder or file not found for ID=0f4db4f2. Skipping.
# Folder or file not found for ID=0f5f3950. Skipping.
# Folder or file not found for ID=0f7f3bf3. Skipping.
# Folder or file not found for ID=0f9b8e65. Skipping.
# Folder or file not found for ID=0fc19fd9. Skipping.
# Folder or file not found for ID=0fced9cd. Skipping.
# Folder or file not found for ID=0ff6ac09. Skipping.
# Folder or file not found for ID=0ff71f1a. Skipping.
# Folder or file not found for ID=0ffadbba. Skipping.
# Folder or file not found for ID=10258585. Skipping.
# Folder or file not found for ID=102e8b66. Skipping.
# Folder or file not found for ID=105a2475. Skipping.
# Folder or file not found for ID=105e3f96. Skipping.
# Folder or file not found for ID=10a3ff78. Skipping.
# Folder or file not found for ID=10be7f09. Skipping.
# Folder or file not found for ID=10c0e99a. Skipping.
# Folder or file not found for ID=10ea0f7e. Skipping.
# Folder or file not found for ID=112a4635. Skipping.
# Folder or file not found for ID=113ef295. Skipping.
# Folder or file not found for ID=11477ed0. Skipping.
# Folder or file not found for ID=1159902c. Skipping.
# Folder or file not found for ID=115d3db4. Skipping.
# Folder or file not found for ID=1169a538. Skipping.
# Folder or file not found for ID=1184a14a. Skipping.
# Folder or file not found for ID=1187440a. Skipping.
# Folder or file not found for ID=118b7733. Skipping.
# Folder or file not found for ID=119dd2e1. Skipping.
# Folder or file not found for ID=11d1a5ac. Skipping.
# Folder or file not found for ID=11dc7b56. Skipping.
# Folder or file not found for ID=11f7253c. Skipping.
# Folder or file not found for ID=1205bbc5. Skipping.
# Folder or file not found for ID=1225fd28. Skipping.
# Folder or file not found for ID=123e0518. Skipping.
# Folder or file not found for ID=125175e1. Skipping.
# Folder or file not found for ID=1262c9df. Skipping.
# Folder or file not found for ID=1282c17a. Skipping.
# Folder or file not found for ID=1286dab7. Skipping.
# Folder or file not found for ID=12a6d170. Skipping.
# Folder or file not found for ID=12cbf30c. Skipping.
# Folder or file not found for ID=12cfb064. Skipping.
# Folder or file not found for ID=12e5069f. Skipping.
# Folder or file not found for ID=12f37ff2. Skipping.
# Folder or file not found for ID=1306392e. Skipping.
# Folder or file not found for ID=1307c41a. Skipping.
# Folder or file not found for ID=132a3165. Skipping.
# Folder or file not found for ID=135af3fb. Skipping.
# Folder or file not found for ID=136894bc. Skipping.
# Folder or file not found for ID=137fc699. Skipping.
# Folder or file not found for ID=13a5e288. Skipping.
# Folder or file not found for ID=13b5ac0f. Skipping.
# Folder or file not found for ID=13be5672. Skipping.
# Folder or file not found for ID=13cdb63a. Skipping.
# Folder or file not found for ID=13d23890. Skipping.
# Folder or file not found for ID=13d2c419. Skipping.
# Folder or file not found for ID=13e15532. Skipping.
# Folder or file not found for ID=13e46923. Skipping.
# Folder or file not found for ID=13efe653. Skipping.
# Folder or file not found for ID=14109652. Skipping.
# Folder or file not found for ID=1420b16e. Skipping.
# Folder or file not found for ID=142242d9. Skipping.
# Folder or file not found for ID=1427e325. Skipping.
# Folder or file not found for ID=1429abf1. Skipping.
# Folder or file not found for ID=1455e657. Skipping.
# Folder or file not found for ID=1458a9d2. Skipping.
# Folder or file not found for ID=147c4374. Skipping.
# Folder or file not found for ID=14b8dd2a. Skipping.
# Folder or file not found for ID=14b999b6. Skipping.
# Folder or file not found for ID=14c12974. Skipping.
# Folder or file not found for ID=14dae995. Skipping.
# Folder or file not found for ID=14e00ce0. Skipping.
# Folder or file not found for ID=14eac885. Skipping.
# Folder or file not found for ID=15132a7e. Skipping.
# Folder or file not found for ID=151bf768. Skipping.
# Folder or file not found for ID=1522fee1. Skipping.
# Folder or file not found for ID=153b6c12. Skipping.
# Folder or file not found for ID=1551c806. Skipping.
# Folder or file not found for ID=1562998a. Skipping.
# Folder or file not found for ID=157b271f. Skipping.
# Folder or file not found for ID=1582a4cb. Skipping.
# Folder or file not found for ID=1586ae0d. Skipping.
# Folder or file not found for ID=15961649. Skipping.
# Folder or file not found for ID=15a2364d. Skipping.
# Folder or file not found for ID=15c8f4d0. Skipping.
# Folder or file not found for ID=15d702f8. Skipping.
# Folder or file not found for ID=15e0568a. Skipping.
# Folder or file not found for ID=164b29ed. Skipping.
# Folder or file not found for ID=164edc75. Skipping.
# Folder or file not found for ID=1655fa88. Skipping.
# Folder or file not found for ID=1661fd48. Skipping.
# Folder or file not found for ID=16a8495c. Skipping.
# Folder or file not found for ID=16bf9efe. Skipping.
# Folder or file not found for ID=16deb306. Skipping.
# Folder or file not found for ID=16e23cca. Skipping.
# Folder or file not found for ID=16e277aa. Skipping.
# Folder or file not found for ID=1704e646. Skipping.
# Folder or file not found for ID=1713348a. Skipping.
# Folder or file not found for ID=176f33fb. Skipping.
# Folder or file not found for ID=1779e997. Skipping.
# Folder or file not found for ID=177f25ab. Skipping.
# Folder or file not found for ID=17994e1d. Skipping.
# Folder or file not found for ID=17b08109. Skipping.
# Folder or file not found for ID=17e9cba0. Skipping.
# Folder or file not found for ID=17f9beca. Skipping.
# Folder or file not found for ID=18003485. Skipping.
# Folder or file not found for ID=181172fe. Skipping.
# Folder or file not found for ID=18154f3a. Skipping.
# Folder or file not found for ID=1824417f. Skipping.
# Folder or file not found for ID=18350390. Skipping.
# Folder or file not found for ID=18400e8e. Skipping.
# Folder or file not found for ID=18406565. Skipping.
# Folder or file not found for ID=1843760e. Skipping.
# Folder or file not found for ID=184f1b4b. Skipping.
# Folder or file not found for ID=1850322c. Skipping.
# Folder or file not found for ID=18506cf3. Skipping.
# Folder or file not found for ID=1866767b. Skipping.
# Folder or file not found for ID=187779ed. Skipping.
# Folder or file not found for ID=187b1802. Skipping.
# Folder or file not found for ID=1894884e. Skipping.
# Folder or file not found for ID=18962676. Skipping.
# Folder or file not found for ID=18ab47f8. Skipping.
# Folder or file not found for ID=18b79e9b. Skipping.
# Folder or file not found for ID=18c8541a. Skipping.
# Folder or file not found for ID=18e21bf1. Skipping.
# Folder or file not found for ID=18f6e6db. Skipping.
# Folder or file not found for ID=18fdbccc. Skipping.
# Folder or file not found for ID=18feab0f. Skipping.
# Folder or file not found for ID=19066573. Skipping.
# Folder or file not found for ID=19381499. Skipping.
# Folder or file not found for ID=1943fb23. Skipping.
# Folder or file not found for ID=1949438b. Skipping.
# Folder or file not found for ID=195f18ab. Skipping.
# Folder or file not found for ID=198e50c9. Skipping.
# Folder or file not found for ID=199c885a. Skipping.
# Folder or file not found for ID=19b095d5. Skipping.
# Folder or file not found for ID=19c49039. Skipping.
# Folder or file not found for ID=19c870f0. Skipping.
# Folder or file not found for ID=19cc95e8. Skipping.
# Folder or file not found for ID=19ed1618. Skipping.
# Folder or file not found for ID=1a1ada0d. Skipping.
# Folder or file not found for ID=1a1e8ac5. Skipping.
# Folder or file not found for ID=1a23d282. Skipping.
# Folder or file not found for ID=1a2412b3. Skipping.
# Folder or file not found for ID=1a42abcc. Skipping.
# Folder or file not found for ID=1a510bfd. Skipping.
# Folder or file not found for ID=1a752b1a. Skipping.
# Folder or file not found for ID=1a7df719. Skipping.
# Folder or file not found for ID=1a92749e. Skipping.
# Folder or file not found for ID=1a9e4b04. Skipping.
# Folder or file not found for ID=1a9f8375. Skipping.
# Folder or file not found for ID=1ad1ab77. Skipping.
# Folder or file not found for ID=1adab915. Skipping.
# Folder or file not found for ID=1afa48fe. Skipping.
# Folder or file not found for ID=1b13223c. Skipping.
# Folder or file not found for ID=1b258140. Skipping.
# Folder or file not found for ID=1b2cd439. Skipping.
# Folder or file not found for ID=1b410106. Skipping.
# Folder or file not found for ID=1b496c35. Skipping.
# Folder or file not found for ID=1b49c870. Skipping.
# Folder or file not found for ID=1b5fb26f. Skipping.
# Folder or file not found for ID=1b5fd952. Skipping.
# Folder or file not found for ID=1b6be334. Skipping.
# Folder or file not found for ID=1b73fce0. Skipping.
# Folder or file not found for ID=1ba0652b. Skipping.
# Folder or file not found for ID=1bbba3ff. Skipping.
# Folder or file not found for ID=1bc6a98c. Skipping.
# Folder or file not found for ID=1bceace4. Skipping.
# Folder or file not found for ID=1c036e73. Skipping.
# Folder or file not found for ID=1c1270a8. Skipping.
# Folder or file not found for ID=1c34a090. Skipping.
# Folder or file not found for ID=1c3b7f1a. Skipping.
# Folder or file not found for ID=1c3c2b2f. Skipping.
# Folder or file not found for ID=1c3fd520. Skipping.
# Folder or file not found for ID=1c481537. Skipping.
# Folder or file not found for ID=1c66daf4. Skipping.
# Folder or file not found for ID=1c673231. Skipping.
# Folder or file not found for ID=1c6ac3d4. Skipping.
# Folder or file not found for ID=1ccf44f0. Skipping.
# Folder or file not found for ID=1ce16ede. Skipping.
# Folder or file not found for ID=1cf6dcef. Skipping.
# Folder or file not found for ID=1d02812a. Skipping.
# Folder or file not found for ID=1d041232. Skipping.
# Folder or file not found for ID=1d11d488. Skipping.
# Folder or file not found for ID=1d3dc8b3. Skipping.
# Folder or file not found for ID=1d41578e. Skipping.
# Folder or file not found for ID=1d44d99b. Skipping.
# Folder or file not found for ID=1d63da6a. Skipping.
# Folder or file not found for ID=1d7edb86. Skipping.
# Folder or file not found for ID=1da37c60. Skipping.
# Folder or file not found for ID=1dd90b53. Skipping.
# Folder or file not found for ID=1de34522. Skipping.
# Folder or file not found for ID=1de3c240. Skipping.
# Folder or file not found for ID=1de762f1. Skipping.
# Folder or file not found for ID=1dfd6433. Skipping.
# Folder or file not found for ID=1e292d2f. Skipping.
# Folder or file not found for ID=1e2a1bd0. Skipping.
# Folder or file not found for ID=1e7dd854. Skipping.
# Folder or file not found for ID=1e986f93. Skipping.
# Folder or file not found for ID=1eb206f0. Skipping.
# Folder or file not found for ID=1ed564ef. Skipping.
# Folder or file not found for ID=1eea376f. Skipping.
# Folder or file not found for ID=1f0aa085. Skipping.
# Folder or file not found for ID=1f0f118d. Skipping.
# Folder or file not found for ID=1f1205b2. Skipping.
# Folder or file not found for ID=1f400626. Skipping.
# Folder or file not found for ID=1f5cefcc. Skipping.
# Folder or file not found for ID=1f7ec039. Skipping.
# Folder or file not found for ID=1f881e3d. Skipping.
# Folder or file not found for ID=1f95c51b. Skipping.
# Folder or file not found for ID=1f97a307. Skipping.
# Folder or file not found for ID=1feb42f2. Skipping.
# Folder or file not found for ID=1ffede3b. Skipping.
# Folder or file not found for ID=200af20c. Skipping.
# Folder or file not found for ID=20565aae. Skipping.
# Folder or file not found for ID=206c8562. Skipping.
# Folder or file not found for ID=2084c823. Skipping.
# Folder or file not found for ID=209471ef. Skipping.
# Folder or file not found for ID=20a67f23. Skipping.
# Folder or file not found for ID=20c37863. Skipping.
# Folder or file not found for ID=20cefbaf. Skipping.
# Folder or file not found for ID=20d7ecfd. Skipping.
# Folder or file not found for ID=20df4cab. Skipping.
# Folder or file not found for ID=20e8ca68. Skipping.
# Folder or file not found for ID=20ff26ce. Skipping.
# Folder or file not found for ID=210baa62. Skipping.
# Folder or file not found for ID=2114473a. Skipping.
# Folder or file not found for ID=217ce5e6. Skipping.
# Folder or file not found for ID=2197f92c. Skipping.
# Folder or file not found for ID=21ae3c82. Skipping.
# Folder or file not found for ID=21b835ac. Skipping.
# Folder or file not found for ID=21c62163. Skipping.
# Folder or file not found for ID=21db593a. Skipping.
# Folder or file not found for ID=21e5833c. Skipping.
# Folder or file not found for ID=21f58fba. Skipping.
# Folder or file not found for ID=223724b2. Skipping.
# Folder or file not found for ID=22389051. Skipping.
# Folder or file not found for ID=22447a95. Skipping.
# Folder or file not found for ID=224dfbfc. Skipping.
# Folder or file not found for ID=2275e6d5. Skipping.
# Folder or file not found for ID=22776248. Skipping.
# Folder or file not found for ID=2282b403. Skipping.
# Folder or file not found for ID=22a71606. Skipping.
# Folder or file not found for ID=22d116bd. Skipping.
# Folder or file not found for ID=22f7ddb8. Skipping.
# Folder or file not found for ID=22f99fea. Skipping.
# Folder or file not found for ID=231f6db4. Skipping.
# Folder or file not found for ID=232b7cb1. Skipping.
# Folder or file not found for ID=232ee0c9. Skipping.
# Folder or file not found for ID=2340e84a. Skipping.
# Folder or file not found for ID=23418fa2. Skipping.
# Folder or file not found for ID=236d450e. Skipping.
# Folder or file not found for ID=236ecde8. Skipping.
# Folder or file not found for ID=23bd890b. Skipping.
# Folder or file not found for ID=23d1a58d. Skipping.
# Folder or file not found for ID=23d71e37. Skipping.
# Folder or file not found for ID=23e7f79b. Skipping.
# Folder or file not found for ID=23ff8272. Skipping.
# Folder or file not found for ID=240a2450. Skipping.
# Folder or file not found for ID=243635c2. Skipping.
# Folder or file not found for ID=24591f4d. Skipping.
# Folder or file not found for ID=247172f9. Skipping.
# Folder or file not found for ID=249b6d68. Skipping.
# Folder or file not found for ID=249d2266. Skipping.
# Folder or file not found for ID=24b4bc6d. Skipping.
# Folder or file not found for ID=24b75658. Skipping.
# Folder or file not found for ID=24dac645. Skipping.
# Folder or file not found for ID=24fb56db. Skipping.
# Folder or file not found for ID=25049e5c. Skipping.
# Folder or file not found for ID=2506e8aa. Skipping.
# Folder or file not found for ID=2522ab31. Skipping.
# Folder or file not found for ID=252ebc5b. Skipping.
# Folder or file not found for ID=253f5cb1. Skipping.
# Folder or file not found for ID=257bf189. Skipping.
# Folder or file not found for ID=25834ba8. Skipping.
# Folder or file not found for ID=2586774b. Skipping.
# Folder or file not found for ID=25e2cbc3. Skipping.
# Folder or file not found for ID=25e752c8. Skipping.
# Folder or file not found for ID=25ff8d4d. Skipping.
# Folder or file not found for ID=260c5288. Skipping.
# Folder or file not found for ID=2625767f. Skipping.
# Folder or file not found for ID=262cff6d. Skipping.
# Folder or file not found for ID=2654b1b9. Skipping.
# Folder or file not found for ID=26891dbd. Skipping.
# Folder or file not found for ID=269d9918. Skipping.
# Folder or file not found for ID=269e06d1. Skipping.
# Folder or file not found for ID=26a4b61b. Skipping.
# Folder or file not found for ID=26b1792f. Skipping.
# Folder or file not found for ID=26b893f4. Skipping.
# Folder or file not found for ID=26c7183b. Skipping.
# Folder or file not found for ID=26d31613. Skipping.
# Folder or file not found for ID=26f0e055. Skipping.
# Folder or file not found for ID=2708b80d. Skipping.
# Folder or file not found for ID=2715347c. Skipping.
# Folder or file not found for ID=273c8ebd. Skipping.
# Folder or file not found for ID=273f11aa. Skipping.
# Folder or file not found for ID=275769c4. Skipping.
# Folder or file not found for ID=27724073. Skipping.
# Folder or file not found for ID=277f5b32. Skipping.
# Folder or file not found for ID=279d0ec4. Skipping.
# Folder or file not found for ID=27cd2a6c. Skipping.
# Folder or file not found for ID=27d363de. Skipping.
# Folder or file not found for ID=27e0ca6b. Skipping.
# Folder or file not found for ID=27f22533. Skipping.
# Folder or file not found for ID=27f8e149. Skipping.
# Folder or file not found for ID=2805045a. Skipping.
# Folder or file not found for ID=2808658d. Skipping.
# Folder or file not found for ID=281174c9. Skipping.
# Folder or file not found for ID=282fa982. Skipping.
# Folder or file not found for ID=284e8ef9. Skipping.
# Folder or file not found for ID=287390e6. Skipping.
# Folder or file not found for ID=287f1349. Skipping.
# Folder or file not found for ID=2891e36b. Skipping.
# Folder or file not found for ID=2898e9d3. Skipping.
# Folder or file not found for ID=28b91cf3. Skipping.
# Folder or file not found for ID=28ba92e9. Skipping.
# Folder or file not found for ID=28e370f4. Skipping.
# Folder or file not found for ID=28e8b2b2. Skipping.
# Folder or file not found for ID=28f7e6ff. Skipping.
# Folder or file not found for ID=28f99ddb. Skipping.
# Folder or file not found for ID=28fd1da9. Skipping.
# Folder or file not found for ID=2911bcab. Skipping.
# Folder or file not found for ID=2911ef94. Skipping.
# Folder or file not found for ID=29886a85. Skipping.
# Folder or file not found for ID=2995b1c3. Skipping.
# Folder or file not found for ID=29a1d334. Skipping.
# Folder or file not found for ID=29e4911b. Skipping.
# Folder or file not found for ID=2a004ad9. Skipping.
# Folder or file not found for ID=2a2550a4. Skipping.
# Folder or file not found for ID=2a320cba. Skipping.
# Folder or file not found for ID=2a3a97de. Skipping.
# Folder or file not found for ID=2a64085d. Skipping.
# Folder or file not found for ID=2a7b5b79. Skipping.
# Folder or file not found for ID=2a81925b. Skipping.
# Folder or file not found for ID=2a85889c. Skipping.
# Folder or file not found for ID=2a880860. Skipping.
# Folder or file not found for ID=2a8ada58. Skipping.
# Folder or file not found for ID=2a8ea138. Skipping.
# Folder or file not found for ID=2aa01109. Skipping.
# Folder or file not found for ID=2aa15e6b. Skipping.
# Folder or file not found for ID=2aab37ac. Skipping.
# Folder or file not found for ID=2af3c8d8. Skipping.
# Folder or file not found for ID=2af988a1. Skipping.
# Folder or file not found for ID=2afee795. Skipping.
# Folder or file not found for ID=2b3a6805. Skipping.
# Folder or file not found for ID=2b4c6c98. Skipping.
# Folder or file not found for ID=2b574ef7. Skipping.
# Folder or file not found for ID=2bad0db7. Skipping.
# Folder or file not found for ID=2bbbdba7. Skipping.
# Folder or file not found for ID=2bca454a. Skipping.
# Folder or file not found for ID=2bcbfb15. Skipping.
# Folder or file not found for ID=2bd186e8. Skipping.
# Folder or file not found for ID=2beaaf7a. Skipping.
# Folder or file not found for ID=2bfc9187. Skipping.
# Folder or file not found for ID=2c30ef79. Skipping.
# Folder or file not found for ID=2c49257f. Skipping.
# Folder or file not found for ID=2c512f2f. Skipping.
# Folder or file not found for ID=2c56c930. Skipping.
# Folder or file not found for ID=2c81a9d4. Skipping.
# Folder or file not found for ID=2c86162c. Skipping.
# Folder or file not found for ID=2c913f37. Skipping.
# Folder or file not found for ID=2c9a90e9. Skipping.
# Folder or file not found for ID=2ca9811d. Skipping.
# Folder or file not found for ID=2cc4b720. Skipping.
# Folder or file not found for ID=2cd9c56b. Skipping.
# Folder or file not found for ID=2cda1052. Skipping.
# Folder or file not found for ID=2cebc0d1. Skipping.
# Folder or file not found for ID=2d043af7. Skipping.
# Folder or file not found for ID=2d0f9f5a. Skipping.
# Folder or file not found for ID=2d286c59. Skipping.
# Folder or file not found for ID=2d38b5c0. Skipping.
# Folder or file not found for ID=2d3ba6fa. Skipping.
# Folder or file not found for ID=2d5365c6. Skipping.
# Folder or file not found for ID=2d6668f1. Skipping.
# Folder or file not found for ID=2d6a0178. Skipping.
# Folder or file not found for ID=2d87fc7d. Skipping.
# Folder or file not found for ID=2dbdfe11. Skipping.
# Folder or file not found for ID=2dc8340e. Skipping.
# Folder or file not found for ID=2dca03d9. Skipping.
# Folder or file not found for ID=2dcaf7cd. Skipping.
# Folder or file not found for ID=2e12e513. Skipping.
# Folder or file not found for ID=2e16053c. Skipping.
# Folder or file not found for ID=2e20c561. Skipping.
# Folder or file not found for ID=2e293d08. Skipping.
# Folder or file not found for ID=2e42573e. Skipping.
# Folder or file not found for ID=2e4df75a. Skipping.
# Folder or file not found for ID=2e4e045a. Skipping.
# Folder or file not found for ID=2e71d21d. Skipping.
# Folder or file not found for ID=2e7d888c. Skipping.
# Folder or file not found for ID=2e8c9884. Skipping.
# Folder or file not found for ID=2ea277d5. Skipping.
# Folder or file not found for ID=2ebdadbc. Skipping.
# Folder or file not found for ID=2f044457. Skipping.
# Folder or file not found for ID=2f0f2949. Skipping.
# Folder or file not found for ID=2f12de00. Skipping.
# Folder or file not found for ID=2f37677d. Skipping.
# Folder or file not found for ID=2f6b484c. Skipping.
# Folder or file not found for ID=2f72f441. Skipping.
# Folder or file not found for ID=2f7f0eb7. Skipping.
# Folder or file not found for ID=2f81950d. Skipping.
# Folder or file not found for ID=2f91f3c1. Skipping.
# Folder or file not found for ID=2fc568f6. Skipping.
# Folder or file not found for ID=2ff729d3. Skipping.
# Folder or file not found for ID=3032421f. Skipping.
# Folder or file not found for ID=3046a5c7. Skipping.
# Folder or file not found for ID=3055881a. Skipping.
# Folder or file not found for ID=307c91ee. Skipping.
# Folder or file not found for ID=3093d29f. Skipping.
# Folder or file not found for ID=30a1d8fe. Skipping.
# Folder or file not found for ID=30ac8a84. Skipping.
# Folder or file not found for ID=30b3f203. Skipping.
# Folder or file not found for ID=30ba4252. Skipping.
# Folder or file not found for ID=3104c361. Skipping.
# Folder or file not found for ID=3133a6c9. Skipping.
# Folder or file not found for ID=31349d8b. Skipping.
# Folder or file not found for ID=3134b69f. Skipping.
# Folder or file not found for ID=3146f878. Skipping.
# Folder or file not found for ID=3155ed01. Skipping.
# Folder or file not found for ID=3162c492. Skipping.
# Folder or file not found for ID=318ccc0e. Skipping.
# Folder or file not found for ID=319ea3cd. Skipping.
# Folder or file not found for ID=31a02566. Skipping.
# Folder or file not found for ID=31d7a136. Skipping.
# Folder or file not found for ID=31dc038d. Skipping.
# Folder or file not found for ID=31ddec50. Skipping.
# Folder or file not found for ID=3204a251. Skipping.
# Folder or file not found for ID=320991a5. Skipping.
# Folder or file not found for ID=3210e833. Skipping.
# Folder or file not found for ID=323ea319. Skipping.
# Folder or file not found for ID=326c23c2. Skipping.
# Folder or file not found for ID=327736cd. Skipping.
# Folder or file not found for ID=32857755. Skipping.
# Folder or file not found for ID=329a9c25. Skipping.
# Folder or file not found for ID=32a9dac0. Skipping.
# Folder or file not found for ID=32c04f66. Skipping.
# Folder or file not found for ID=32d0ebca. Skipping.
# Folder or file not found for ID=32d262c2. Skipping.
# Folder or file not found for ID=32e18ccc. Skipping.
# Folder or file not found for ID=3302713b. Skipping.
# Folder or file not found for ID=3305a981. Skipping.
# Folder or file not found for ID=331c5a4a. Skipping.
# Folder or file not found for ID=3327956c. Skipping.
# Folder or file not found for ID=333af713. Skipping.
# Folder or file not found for ID=333be478. Skipping.
# Folder or file not found for ID=3375a49c. Skipping.
# Folder or file not found for ID=337c4d94. Skipping.
# Folder or file not found for ID=3399795b. Skipping.
# Folder or file not found for ID=33a499ce. Skipping.
# Folder or file not found for ID=33e34de8. Skipping.
# Folder or file not found for ID=33f9c85b. Skipping.
# Folder or file not found for ID=34124db3. Skipping.
# Folder or file not found for ID=342d43c7. Skipping.
# Folder or file not found for ID=342edae9. Skipping.
# Folder or file not found for ID=343460ab. Skipping.
# Folder or file not found for ID=3441fd41. Skipping.
# Folder or file not found for ID=3466c72a. Skipping.
# Folder or file not found for ID=347095fe. Skipping.
# Folder or file not found for ID=347d2af9. Skipping.
# Folder or file not found for ID=348136b6. Skipping.
# Folder or file not found for ID=3492ccbd. Skipping.
# Folder or file not found for ID=34af3570. Skipping.
# Folder or file not found for ID=34c30fad. Skipping.
# Folder or file not found for ID=34d1aacc. Skipping.
# Folder or file not found for ID=34eb79f9. Skipping.
# Folder or file not found for ID=35265670. Skipping.
# Folder or file not found for ID=35272f43. Skipping.
# Folder or file not found for ID=355bb19a. Skipping.
# Folder or file not found for ID=356ab908. Skipping.
# Folder or file not found for ID=3599e9d7. Skipping.
# Folder or file not found for ID=35a94642. Skipping.
# Folder or file not found for ID=35c49344. Skipping.
# Folder or file not found for ID=35fe98b3. Skipping.
# Folder or file not found for ID=36146fe1. Skipping.
# Folder or file not found for ID=3617e141. Skipping.
# Folder or file not found for ID=3622933f. Skipping.
# Folder or file not found for ID=36473697. Skipping.
# Folder or file not found for ID=364afc11. Skipping.
# Folder or file not found for ID=3655395c. Skipping.
# Folder or file not found for ID=366142d3. Skipping.
# Folder or file not found for ID=3661e257. Skipping.
# Folder or file not found for ID=366d28a8. Skipping.
# Folder or file not found for ID=367cc279. Skipping.
# Folder or file not found for ID=36958957. Skipping.
# Folder or file not found for ID=36b8c9e5. Skipping.
# Folder or file not found for ID=36cd03cf. Skipping.
# Folder or file not found for ID=36e77bf0. Skipping.
# Folder or file not found for ID=36fda5de. Skipping.
# Folder or file not found for ID=3709416b. Skipping.
# Folder or file not found for ID=370b47c4. Skipping.
# Folder or file not found for ID=3714afd7. Skipping.
# Folder or file not found for ID=3720e5a7. Skipping.
# Folder or file not found for ID=3728a93f. Skipping.
# Folder or file not found for ID=3738db26. Skipping.
# Folder or file not found for ID=374d3984. Skipping.
# Folder or file not found for ID=375e2ee5. Skipping.
# Folder or file not found for ID=376e617f. Skipping.
# Folder or file not found for ID=379d558f. Skipping.
# Folder or file not found for ID=37ddc2cf. Skipping.
# Folder or file not found for ID=38137f22. Skipping.
# Folder or file not found for ID=3820a945. Skipping.
# Folder or file not found for ID=38390669. Skipping.
# Folder or file not found for ID=383ab806. Skipping.
# Folder or file not found for ID=383d2ad2. Skipping.
# Folder or file not found for ID=384b83f9. Skipping.
# Folder or file not found for ID=385819e6. Skipping.
# Folder or file not found for ID=385a6557. Skipping.
# Folder or file not found for ID=3864dd31. Skipping.
# Folder or file not found for ID=38aa4aed. Skipping.
# Folder or file not found for ID=38cc02b7. Skipping.
# Folder or file not found for ID=38df3cc5. Skipping.
# Folder or file not found for ID=38edfccd. Skipping.
# Folder or file not found for ID=38ee12e7. Skipping.
# Folder or file not found for ID=3901e707. Skipping.
# Folder or file not found for ID=3909a855. Skipping.
# Folder or file not found for ID=3913797d. Skipping.
# Folder or file not found for ID=3918d854. Skipping.
# Folder or file not found for ID=3934e29c. Skipping.
# Folder or file not found for ID=394684ae. Skipping.
# Folder or file not found for ID=394a6219. Skipping.
# Folder or file not found for ID=39697713. Skipping.
# Folder or file not found for ID=3999e449. Skipping.
# Folder or file not found for ID=39bdbb00. Skipping.
# Folder or file not found for ID=39c20e2a. Skipping.
# Folder or file not found for ID=39cc2836. Skipping.
# Folder or file not found for ID=39d626f4. Skipping.
# Folder or file not found for ID=39dd3538. Skipping.
# Folder or file not found for ID=39dfffd1. Skipping.
# Folder or file not found for ID=3a33d579. Skipping.
# Folder or file not found for ID=3a7154ef. Skipping.
# Folder or file not found for ID=3a9d7bd6. Skipping.
# Folder or file not found for ID=3aa62ad8. Skipping.
# Folder or file not found for ID=3ab0b1ff. Skipping.
# Folder or file not found for ID=3ae4ee9b. Skipping.
# Folder or file not found for ID=3b047021. Skipping.
# Folder or file not found for ID=3b0f680f. Skipping.
# Folder or file not found for ID=3b112284. Skipping.
# Folder or file not found for ID=3b7f721f. Skipping.
# Folder or file not found for ID=3b98f56f. Skipping.
# Folder or file not found for ID=3ba435d2. Skipping.
# Folder or file not found for ID=3bbf88cd. Skipping.
# Folder or file not found for ID=3bf75b68. Skipping.
# Folder or file not found for ID=3c2df645. Skipping.
# Folder or file not found for ID=3c5c85e7. Skipping.
# Folder or file not found for ID=3c6f9125. Skipping.
# Folder or file not found for ID=3c7a7f32. Skipping.
# Folder or file not found for ID=3cb2c4da. Skipping.
# Folder or file not found for ID=3cb5deff. Skipping.
# Folder or file not found for ID=3cc9cfa6. Skipping.
# Folder or file not found for ID=3cd25935. Skipping.
# Folder or file not found for ID=3cd8802e. Skipping.
# Folder or file not found for ID=3cfeca85. Skipping.
# Folder or file not found for ID=3d04e8d3. Skipping.
# Folder or file not found for ID=3d20d9a7. Skipping.
# Folder or file not found for ID=3d2c0bc5. Skipping.
# Folder or file not found for ID=3d3fb503. Skipping.
# Folder or file not found for ID=3d46429f. Skipping.
# Folder or file not found for ID=3d5acaf4. Skipping.
# Folder or file not found for ID=3d5ad997. Skipping.
# Folder or file not found for ID=3d8531f5. Skipping.
# Folder or file not found for ID=3dcbc164. Skipping.
# Folder or file not found for ID=3dce8a87. Skipping.
# Folder or file not found for ID=3de1a622. Skipping.
# Folder or file not found for ID=3de6a21c. Skipping.
# Folder or file not found for ID=3e2383b5. Skipping.
# Folder or file not found for ID=3e377cb7. Skipping.
# Folder or file not found for ID=3e3c242c. Skipping.
# Folder or file not found for ID=3e42fb00. Skipping.
# Folder or file not found for ID=3e71dba8. Skipping.
# Folder or file not found for ID=3e7ee995. Skipping.
# Folder or file not found for ID=3e9fd8d6. Skipping.
# Folder or file not found for ID=3eb48980. Skipping.
# Folder or file not found for ID=3ebfbb4c. Skipping.
# Folder or file not found for ID=3ede35d1. Skipping.
# Folder or file not found for ID=3f20e14b. Skipping.
# Folder or file not found for ID=3f2141da. Skipping.
# Folder or file not found for ID=3f36989c. Skipping.
# Folder or file not found for ID=3f3a70c8. Skipping.
# Folder or file not found for ID=3f3d3809. Skipping.
# Folder or file not found for ID=3f51a21d. Skipping.
# Folder or file not found for ID=3fb896a9. Skipping.
# Folder or file not found for ID=3fe47b69. Skipping.
# Folder or file not found for ID=3fe59141. Skipping.
# Folder or file not found for ID=3fe78116. Skipping.
# Folder or file not found for ID=3ffca4a4. Skipping.
# Folder or file not found for ID=4003e648. Skipping.
# Folder or file not found for ID=40109473. Skipping.
# Folder or file not found for ID=4057472d. Skipping.
# Folder or file not found for ID=40898508. Skipping.
# Folder or file not found for ID=4093774d. Skipping.
# Folder or file not found for ID=40b520f0. Skipping.
# Folder or file not found for ID=40b904b3. Skipping.
# Folder or file not found for ID=40cdadfc. Skipping.
# Folder or file not found for ID=40e95163. Skipping.
# Folder or file not found for ID=41052ced. Skipping.
# Folder or file not found for ID=41185f8e. Skipping.
# Folder or file not found for ID=4128aee6. Skipping.
# Folder or file not found for ID=4135cb0e. Skipping.
# Folder or file not found for ID=4157be55. Skipping.
# Folder or file not found for ID=415cf055. Skipping.
# Folder or file not found for ID=415d5a1a. Skipping.
# Folder or file not found for ID=4178a68d. Skipping.
# Folder or file not found for ID=41974cde. Skipping.
# Folder or file not found for ID=41b66459. Skipping.
# Folder or file not found for ID=41bacefb. Skipping.
# Folder or file not found for ID=41badf5d. Skipping.
# Folder or file not found for ID=41cfd1db. Skipping.
# Folder or file not found for ID=41d48900. Skipping.
# Folder or file not found for ID=41ec1042. Skipping.
# Folder or file not found for ID=42309938. Skipping.
# Folder or file not found for ID=423610ac. Skipping.
# Folder or file not found for ID=4248261f. Skipping.
# Folder or file not found for ID=4255e559. Skipping.
# Folder or file not found for ID=4262ce3d. Skipping.
# Folder or file not found for ID=4268ce08. Skipping.
# Folder or file not found for ID=427fad9e. Skipping.
# Folder or file not found for ID=42aa29fb. Skipping.
# Folder or file not found for ID=42bf071e. Skipping.
# Folder or file not found for ID=42c6f67a. Skipping.
# Folder or file not found for ID=42dfc9dd. Skipping.
# Folder or file not found for ID=42ebc3fd. Skipping.
# Folder or file not found for ID=42edba48. Skipping.
# Folder or file not found for ID=432a4c21. Skipping.
# Folder or file not found for ID=435bfa7b. Skipping.
# Folder or file not found for ID=43808706. Skipping.
# Folder or file not found for ID=439c1716. Skipping.
# Folder or file not found for ID=43d43363. Skipping.
# Folder or file not found for ID=43e54b20. Skipping.
# Folder or file not found for ID=43fb80d6. Skipping.
# Folder or file not found for ID=43fdba8b. Skipping.
# Folder or file not found for ID=44160dec. Skipping.
# Folder or file not found for ID=444131bc. Skipping.
# Folder or file not found for ID=44596139. Skipping.
# Folder or file not found for ID=446757cb. Skipping.
# Folder or file not found for ID=446b29e4. Skipping.
# Folder or file not found for ID=4496d883. Skipping.
# Folder or file not found for ID=44a76f2a. Skipping.
# Folder or file not found for ID=44b27c01. Skipping.
# Folder or file not found for ID=44b8622c. Skipping.
# Folder or file not found for ID=44cbf5c5. Skipping.
# Folder or file not found for ID=44eaea78. Skipping.
# Folder or file not found for ID=4505724a. Skipping.
# Folder or file not found for ID=4507da27. Skipping.
# Folder or file not found for ID=4518ed77. Skipping.
# Folder or file not found for ID=451b0cd9. Skipping.
# Folder or file not found for ID=451c11b3. Skipping.
# Folder or file not found for ID=455ae5db. Skipping.
# Folder or file not found for ID=45759ae9. Skipping.
# Folder or file not found for ID=45a6eecc. Skipping.
# Folder or file not found for ID=45ea366f. Skipping.
# Folder or file not found for ID=45eb32f2. Skipping.
# Folder or file not found for ID=46170319. Skipping.
# Folder or file not found for ID=461e2e46. Skipping.
# Folder or file not found for ID=463bf3b2. Skipping.
# Folder or file not found for ID=4659aa1a. Skipping.
# Folder or file not found for ID=465d3273. Skipping.
# Folder or file not found for ID=46610e5f. Skipping.
# Folder or file not found for ID=466752d9. Skipping.
# Folder or file not found for ID=466a0bc5. Skipping.
# Folder or file not found for ID=46850373. Skipping.
# Folder or file not found for ID=471e4d12. Skipping.
# Folder or file not found for ID=4734a934. Skipping.
# Folder or file not found for ID=473dc7fc. Skipping.
# Folder or file not found for ID=47588d91. Skipping.
# Folder or file not found for ID=475ebe47. Skipping.
# Folder or file not found for ID=4777151c. Skipping.
# Folder or file not found for ID=47a2cce9. Skipping.
# Folder or file not found for ID=47a52eb8. Skipping.
# Folder or file not found for ID=47acbbc6. Skipping.
# Folder or file not found for ID=47b3bea1. Skipping.
# Folder or file not found for ID=47b45998. Skipping.
# Folder or file not found for ID=47c088d9. Skipping.
# Folder or file not found for ID=47c1f368. Skipping.
# Folder or file not found for ID=47c3b47c. Skipping.
# Folder or file not found for ID=47c55e13. Skipping.
# Folder or file not found for ID=47fef4fc. Skipping.
# Folder or file not found for ID=48114f96. Skipping.
# Folder or file not found for ID=4829f7ca. Skipping.
# Folder or file not found for ID=4833c27b. Skipping.
# Folder or file not found for ID=485d7c69. Skipping.
# Folder or file not found for ID=486ba65d. Skipping.
# Folder or file not found for ID=4876cb0f. Skipping.
# Folder or file not found for ID=489fa831. Skipping.
# Folder or file not found for ID=48c205d9. Skipping.
# Folder or file not found for ID=48d285f4. Skipping.
# Folder or file not found for ID=48f3d473. Skipping.
# Folder or file not found for ID=48fab8bb. Skipping.
# Folder or file not found for ID=4916aea0. Skipping.
# Folder or file not found for ID=491bf457. Skipping.
# Folder or file not found for ID=49358287. Skipping.
# Folder or file not found for ID=4942af36. Skipping.
# Folder or file not found for ID=494eba8a. Skipping.
# Folder or file not found for ID=49887971. Skipping.
# Folder or file not found for ID=49909509. Skipping.
# Folder or file not found for ID=499d4499. Skipping.
# Folder or file not found for ID=49b86b1e. Skipping.
# Folder or file not found for ID=49f38606. Skipping.
# Folder or file not found for ID=4a01c5d9. Skipping.
# Folder or file not found for ID=4a0b1b9d. Skipping.
# Folder or file not found for ID=4a21eb0c. Skipping.
# Folder or file not found for ID=4a310295. Skipping.
# Folder or file not found for ID=4a3b6521. Skipping.
# Folder or file not found for ID=4a68d751. Skipping.
# Folder or file not found for ID=4a69e534. Skipping.
# Folder or file not found for ID=4a6ea9de. Skipping.
# Folder or file not found for ID=4a70e025. Skipping.
# Folder or file not found for ID=4a753ca3. Skipping.
# Folder or file not found for ID=4a835866. Skipping.
# Folder or file not found for ID=4aa3deb0. Skipping.
# Folder or file not found for ID=4ac5c412. Skipping.
# Folder or file not found for ID=4acac04e. Skipping.
# Folder or file not found for ID=4ad94d1e. Skipping.
# Folder or file not found for ID=4afa8a76. Skipping.
# Folder or file not found for ID=4b1f6855. Skipping.
# Folder or file not found for ID=4b20bce7. Skipping.
# Folder or file not found for ID=4b328259. Skipping.
# Folder or file not found for ID=4b3db4f4. Skipping.
# Folder or file not found for ID=4b51db3e. Skipping.
# Folder or file not found for ID=4b537ba9. Skipping.
# Folder or file not found for ID=4b65b38d. Skipping.
# Folder or file not found for ID=4b7b35bc. Skipping.
# Folder or file not found for ID=4b855d9d. Skipping.
# Folder or file not found for ID=4b8d6356. Skipping.
# Folder or file not found for ID=4bb9a8ff. Skipping.
# Folder or file not found for ID=4bd08623. Skipping.
# Folder or file not found for ID=4be6f3c1. Skipping.
# Folder or file not found for ID=4c1fa25b. Skipping.
# ...
# Folder or file not found for ID=e3bb3735. Skipping.
# Folder or file not found for ID=e3cec795. Skipping.
# Folder or file not found for ID=e3d5aab8. Skipping.
# Folder or file not found for ID=e3ef6064. Skipping.
# Folder or file not found for ID=e3f239e9. Skipping.
# Folder or file not found for ID=e46334db. Skipping.
# Folder or file not found for ID=e47c1eb7. Skipping.
# Folder or file not found for ID=e490d5c5. Skipping.
# Folder or file not found for ID=e4a2e3bc. Skipping.
# Folder or file not found for ID=e4a790a8. Skipping.
# Folder or file not found for ID=e4c008b9. Skipping.
# Folder or file not found for ID=e4d5bf2b. Skipping.
# Folder or file not found for ID=e4db6712. Skipping.
# Folder or file not found for ID=e4ee6ff3. Skipping.
# Folder or file not found for ID=e515c971. Skipping.
# Folder or file not found for ID=e537418f. Skipping.
# Folder or file not found for ID=e54a78e9. Skipping.
# Folder or file not found for ID=e54b2178. Skipping.
# Folder or file not found for ID=e550946f. Skipping.
# Folder or file not found for ID=e56b2209. Skipping.
# Folder or file not found for ID=e5b902bc. Skipping.
# Folder or file not found for ID=e5d77ff3. Skipping.
# Folder or file not found for ID=e5db13bc. Skipping.
# Folder or file not found for ID=e5defd66. Skipping.
# Folder or file not found for ID=e6169c6d. Skipping.
# Folder or file not found for ID=e6276aaa. Skipping.
# Folder or file not found for ID=e63a0ea8. Skipping.
# Folder or file not found for ID=e664dd71. Skipping.
# Folder or file not found for ID=e670804a. Skipping.
# Folder or file not found for ID=e68cf012. Skipping.
# Folder or file not found for ID=e715739b. Skipping.
# Folder or file not found for ID=e71f347e. Skipping.
# Folder or file not found for ID=e72af462. Skipping.
# Folder or file not found for ID=e735a855. Skipping.
# Folder or file not found for ID=e739c579. Skipping.
# Folder or file not found for ID=e749b8af. Skipping.
# Folder or file not found for ID=e7733d6c. Skipping.
# Folder or file not found for ID=e78faee3. Skipping.
# Folder or file not found for ID=e79487a3. Skipping.
# Folder or file not found for ID=e7a825e6. Skipping.
# Folder or file not found for ID=e7bbb32e. Skipping.
# Folder or file not found for ID=e7cd2202. Skipping.
# Folder or file not found for ID=e7cef620. Skipping.
# Folder or file not found for ID=e7db432d. Skipping.
# Folder or file not found for ID=e7db9aef. Skipping.
# Folder or file not found for ID=e7e43817. Skipping.
# Folder or file not found for ID=e7ee0921. Skipping.
# Folder or file not found for ID=e810389a. Skipping.
# Folder or file not found for ID=e818ad1b. Skipping.
# Folder or file not found for ID=e81bef0e. Skipping.
# Folder or file not found for ID=e8313da5. Skipping.
# Folder or file not found for ID=e838df3b. Skipping.
# Folder or file not found for ID=e86bb780. Skipping.
# Folder or file not found for ID=e86f8006. Skipping.
# Folder or file not found for ID=e8ac21d2. Skipping.
# Folder or file not found for ID=e8af663d. Skipping.
# Folder or file not found for ID=e8c93ca7. Skipping.
# Folder or file not found for ID=e8d9d5ea. Skipping.
# Folder or file not found for ID=e9030ab7. Skipping.
# Folder or file not found for ID=e90a63d0. Skipping.
# Folder or file not found for ID=e9109dff. Skipping.
# Folder or file not found for ID=e912c973. Skipping.
# Folder or file not found for ID=e934bf0a. Skipping.
# Folder or file not found for ID=e93cce44. Skipping.
# Folder or file not found for ID=e943970e. Skipping.
# Folder or file not found for ID=e96763c1. Skipping.
# Folder or file not found for ID=e96da61f. Skipping.
# Folder or file not found for ID=e9a00f71. Skipping.
# Folder or file not found for ID=e9a6c514. Skipping.
# Folder or file not found for ID=e9b642a3. Skipping.
# Folder or file not found for ID=ea221ef5. Skipping.
# Folder or file not found for ID=ea38bd63. Skipping.
# Folder or file not found for ID=ea401fc9. Skipping.
# Folder or file not found for ID=eaa4821d. Skipping.
# Folder or file not found for ID=eab1550c. Skipping.
# Folder or file not found for ID=eac08386. Skipping.
# Folder or file not found for ID=ead25f13. Skipping.
# Folder or file not found for ID=ead871be. Skipping.
# Folder or file not found for ID=eaedb188. Skipping.
# Folder or file not found for ID=eb00abb3. Skipping.
# Folder or file not found for ID=eb1b6325. Skipping.
# Folder or file not found for ID=eb5c46b0. Skipping.
# Folder or file not found for ID=eb731ce2. Skipping.
# Folder or file not found for ID=eb749e46. Skipping.
# Folder or file not found for ID=eb891208. Skipping.
# Folder or file not found for ID=eb8c030f. Skipping.
# Folder or file not found for ID=eb90ee20. Skipping.
# Folder or file not found for ID=eb9a846d. Skipping.
# Folder or file not found for ID=eb9fd2ca. Skipping.
# Folder or file not found for ID=eba27772. Skipping.
# Folder or file not found for ID=ebbc6fea. Skipping.
# Folder or file not found for ID=ebd15fdc. Skipping.
# Folder or file not found for ID=ec015bbb. Skipping.
# Folder or file not found for ID=ec0f4afa. Skipping.
# Folder or file not found for ID=ec220299. Skipping.
# Folder or file not found for ID=ec4a1461. Skipping.
# Folder or file not found for ID=ec619149. Skipping.
# Folder or file not found for ID=ec65cd62. Skipping.
# Folder or file not found for ID=ec850b10. Skipping.
# Folder or file not found for ID=ec890dbd. Skipping.
# Folder or file not found for ID=ec9044f5. Skipping.
# Folder or file not found for ID=ec9179b7. Skipping.
# Folder or file not found for ID=ecac5c72. Skipping.
# Folder or file not found for ID=ecb1c038. Skipping.
# Folder or file not found for ID=ecbdbe55. Skipping.
# Folder or file not found for ID=ecc0cc08. Skipping.
# Folder or file not found for ID=ecd22509. Skipping.
# Folder or file not found for ID=ecd6b424. Skipping.
# Folder or file not found for ID=ed184a43. Skipping.
# Folder or file not found for ID=ed329c15. Skipping.
# Folder or file not found for ID=ed50a6f6. Skipping.
# Folder or file not found for ID=ed60b87e. Skipping.
# Folder or file not found for ID=ed61b01e. Skipping.
# Folder or file not found for ID=edaa11c4. Skipping.
# Folder or file not found for ID=edb50fce. Skipping.
# Folder or file not found for ID=edb86a64. Skipping.
# Folder or file not found for ID=edbf35f3. Skipping.
# Folder or file not found for ID=edc44560. Skipping.
# Folder or file not found for ID=edca760c. Skipping.
# Folder or file not found for ID=edcf632d. Skipping.
# Folder or file not found for ID=edeec50d. Skipping.
# Folder or file not found for ID=edfe1f8d. Skipping.
# Folder or file not found for ID=ee0fa75a. Skipping.
# Folder or file not found for ID=ee4e9eed. Skipping.
# Folder or file not found for ID=ee4fe168. Skipping.
# Folder or file not found for ID=ee654259. Skipping.
# Folder or file not found for ID=ee74be35. Skipping.
# Folder or file not found for ID=ee7de96c. Skipping.
# Folder or file not found for ID=eea74d46. Skipping.
# Folder or file not found for ID=eebce76e. Skipping.
# Folder or file not found for ID=eec0d188. Skipping.
# Folder or file not found for ID=eeefa792. Skipping.
# Folder or file not found for ID=eefeb431. Skipping.
# Folder or file not found for ID=ef0992a2. Skipping.
# Folder or file not found for ID=ef1b858a. Skipping.
# Folder or file not found for ID=ef3a2d17. Skipping.
# Folder or file not found for ID=ef4ae515. Skipping.
# Folder or file not found for ID=ef6f257a. Skipping.
# Folder or file not found for ID=efba7242. Skipping.
# Folder or file not found for ID=efbad88b. Skipping.
# Folder or file not found for ID=efc2bc05. Skipping.
# Folder or file not found for ID=efcef0d6. Skipping.
# Folder or file not found for ID=efedde24. Skipping.
# Folder or file not found for ID=efee1240. Skipping.
# Folder or file not found for ID=f0356a48. Skipping.
# Folder or file not found for ID=f043be76. Skipping.
# Folder or file not found for ID=f05c6580. Skipping.
# Folder or file not found for ID=f07dcfd6. Skipping.
# Folder or file not found for ID=f0856b84. Skipping.
# Folder or file not found for ID=f086b49c. Skipping.
# Folder or file not found for ID=f08a5ac3. Skipping.
# Folder or file not found for ID=f08c830a. Skipping.
# Folder or file not found for ID=f09a076a. Skipping.
# Folder or file not found for ID=f09b02cd. Skipping.
# Folder or file not found for ID=f0b5d026. Skipping.
# Folder or file not found for ID=f0ed5690. Skipping.
# Folder or file not found for ID=f0f199ad. Skipping.
# Folder or file not found for ID=f0f3e41f. Skipping.
# Folder or file not found for ID=f13cb65e. Skipping.
# Folder or file not found for ID=f14e55d7. Skipping.
# Folder or file not found for ID=f15dca1b. Skipping.
# Folder or file not found for ID=f1629e61. Skipping.
# Folder or file not found for ID=f1702318. Skipping.
# Folder or file not found for ID=f1a16e58. Skipping.
# Folder or file not found for ID=f1baabc1. Skipping.
# Folder or file not found for ID=f1c306d5. Skipping.
# Folder or file not found for ID=f1c3cb6b. Skipping.
# Folder or file not found for ID=f1d1273e. Skipping.
# Folder or file not found for ID=f1d26ed5. Skipping.
# Folder or file not found for ID=f1ed2e85. Skipping.
# Folder or file not found for ID=f1ee75bf. Skipping.
# Folder or file not found for ID=f21c19e1. Skipping.
# Folder or file not found for ID=f220a837. Skipping.
# Folder or file not found for ID=f2260009. Skipping.
# Folder or file not found for ID=f237ef1c. Skipping.
# Folder or file not found for ID=f240387a. Skipping.
# Folder or file not found for ID=f2499682. Skipping.
# Folder or file not found for ID=f2649b91. Skipping.
# Folder or file not found for ID=f2932f33. Skipping.
# Folder or file not found for ID=f29d4094. Skipping.
# Folder or file not found for ID=f301e7a9. Skipping.
# Folder or file not found for ID=f3600deb. Skipping.
# Folder or file not found for ID=f3993171. Skipping.
# Folder or file not found for ID=f3a1dd3b. Skipping.
# Folder or file not found for ID=f3aac45a. Skipping.
# Folder or file not found for ID=f3b8becc. Skipping.
# Folder or file not found for ID=f3caf913. Skipping.
# Folder or file not found for ID=f3d22832. Skipping.
# Folder or file not found for ID=f3fbe6c9. Skipping.
# Folder or file not found for ID=f41a21c4. Skipping.
# Folder or file not found for ID=f4223e3a. Skipping.
# Folder or file not found for ID=f433302d. Skipping.
# Folder or file not found for ID=f47714c0. Skipping.
# Folder or file not found for ID=f497dd7b. Skipping.
# Folder or file not found for ID=f4989c06. Skipping.
# Folder or file not found for ID=f4c50c86. Skipping.
# Folder or file not found for ID=f4e9d109. Skipping.
# Folder or file not found for ID=f4ec5449. Skipping.
# Folder or file not found for ID=f4ece6b5. Skipping.
# Folder or file not found for ID=f51eff6a. Skipping.
# Folder or file not found for ID=f52a2597. Skipping.
# Folder or file not found for ID=f5369cea. Skipping.
# Folder or file not found for ID=f54eebeb. Skipping.
# Folder or file not found for ID=f55a1469. Skipping.
# Folder or file not found for ID=f566e5cc. Skipping.
# Folder or file not found for ID=f567a1af. Skipping.
# Folder or file not found for ID=f58ddd4a. Skipping.
# Folder or file not found for ID=f5c5cfee. Skipping.
# Folder or file not found for ID=f5d4c82e. Skipping.
# Folder or file not found for ID=f5d81859. Skipping.
# Folder or file not found for ID=f5e64c94. Skipping.
# Folder or file not found for ID=f5ee91e4. Skipping.
# Folder or file not found for ID=f5efa540. Skipping.
# Folder or file not found for ID=f6284dcb. Skipping.
# Folder or file not found for ID=f64e1d85. Skipping.
# Folder or file not found for ID=f64f877b. Skipping.
# Folder or file not found for ID=f68f158d. Skipping.
# Folder or file not found for ID=f6bcfb38. Skipping.
# Folder or file not found for ID=f6d3a5ad. Skipping.
# Folder or file not found for ID=f74c45c1. Skipping.
# Folder or file not found for ID=f77c2636. Skipping.
# Folder or file not found for ID=f78421c9. Skipping.
# Folder or file not found for ID=f79e6708. Skipping.
# Folder or file not found for ID=f7b24278. Skipping.
# Folder or file not found for ID=f7bb3b1c. Skipping.
# Folder or file not found for ID=f7c08ff0. Skipping.
# Folder or file not found for ID=f7fcb41b. Skipping.
# Folder or file not found for ID=f804c9f3. Skipping.
# Folder or file not found for ID=f817f33a. Skipping.
# Folder or file not found for ID=f82a1183. Skipping.
# Folder or file not found for ID=f848f42b. Skipping.
# Folder or file not found for ID=f84e064d. Skipping.
# Folder or file not found for ID=f897f15d. Skipping.
# Folder or file not found for ID=f8a1b335. Skipping.
# Folder or file not found for ID=f8b08332. Skipping.
# Folder or file not found for ID=f8b36382. Skipping.
# Folder or file not found for ID=f8d293a0. Skipping.
# Folder or file not found for ID=f8d94d02. Skipping.
# Folder or file not found for ID=f8e3467e. Skipping.
# Folder or file not found for ID=f8f5f3df. Skipping.
# Folder or file not found for ID=f91ba8bb. Skipping.
# Folder or file not found for ID=f922ae21. Skipping.
# Folder or file not found for ID=f92475d4. Skipping.
# Folder or file not found for ID=f9273ffc. Skipping.
# Folder or file not found for ID=f958efdc. Skipping.
# Folder or file not found for ID=f9744a50. Skipping.
# Folder or file not found for ID=f9897bf1. Skipping.
# Folder or file not found for ID=f98bde44. Skipping.
# Folder or file not found for ID=f9b73de7. Skipping.
# Folder or file not found for ID=f9ca9ff6. Skipping.
# Folder or file not found for ID=fa293db8. Skipping.
# Folder or file not found for ID=fa29ab47. Skipping.
# Folder or file not found for ID=fa30d545. Skipping.
# Folder or file not found for ID=fa472647. Skipping.
# Folder or file not found for ID=fa4f0329. Skipping.
# Folder or file not found for ID=fa62d7b1. Skipping.
# Folder or file not found for ID=fa78d819. Skipping.
# Folder or file not found for ID=fab6550c. Skipping.
# Folder or file not found for ID=facdd8bf. Skipping.
# Folder or file not found for ID=fad31638. Skipping.
# Folder or file not found for ID=fb111799. Skipping.
# Folder or file not found for ID=fb194aa7. Skipping.
# Folder or file not found for ID=fb22e454. Skipping.
# Folder or file not found for ID=fb2c4db6. Skipping.
# Folder or file not found for ID=fb2ddbd1. Skipping.
# Folder or file not found for ID=fb3c4473. Skipping.
# Folder or file not found for ID=fb6a1b72. Skipping.
# Folder or file not found for ID=fb9982a2. Skipping.
# Folder or file not found for ID=fb9b060f. Skipping.
# Folder or file not found for ID=fbb39bfe. Skipping.
# Folder or file not found for ID=fbbd97b1. Skipping.
# Folder or file not found for ID=fbc6ade7. Skipping.
# Folder or file not found for ID=fbda3966. Skipping.
# Folder or file not found for ID=fbf1f698. Skipping.
# Folder or file not found for ID=fc0eede5. Skipping.
# Folder or file not found for ID=fc1912e3. Skipping.
# Folder or file not found for ID=fc198415. Skipping.
# Folder or file not found for ID=fc290a36. Skipping.
# Folder or file not found for ID=fc633e5a. Skipping.
# Folder or file not found for ID=fc8ba2d9. Skipping.
# Folder or file not found for ID=fc96f532. Skipping.
# Folder or file not found for ID=fcc6347f. Skipping.
# Folder or file not found for ID=fcd9a6bb. Skipping.
# Folder or file not found for ID=fcfadd26. Skipping.
# Folder or file not found for ID=fd226dc3. Skipping.
# Folder or file not found for ID=fd3448d9. Skipping.
# Folder or file not found for ID=fd5589f6. Skipping.
# Folder or file not found for ID=fdb7da3c. Skipping.
# Folder or file not found for ID=fdcb5b38. Skipping.
# Folder or file not found for ID=fdce05a4. Skipping.
# Folder or file not found for ID=fdd9799f. Skipping.
# Folder or file not found for ID=fe102a25. Skipping.
# Folder or file not found for ID=fe2bc235. Skipping.
# Folder or file not found for ID=fe5e2dc9. Skipping.
# Folder or file not found for ID=fe6afaf9. Skipping.
# Folder or file not found for ID=fe7c87e2. Skipping.
# Folder or file not found for ID=fe7f68a7. Skipping.
# Folder or file not found for ID=feb53635. Skipping.
# Folder or file not found for ID=fee07f32. Skipping.
# Folder or file not found for ID=fefaffe0. Skipping.
# Folder or file not found for ID=ff0ab367. Skipping.
# Folder or file not found for ID=ff60112d. Skipping.
# Folder or file not found for ID=ff6c2bb8. Skipping.
# Folder or file not found for ID=ff759544. Skipping.
# Folder or file not found for ID=ff8a2de4. Skipping.
# Folder or file not found for ID=ffa9794a. Skipping.
# Folder or file not found for ID=ffef538e. Skipping.

# %%
final_data
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# 0         Winter             51.0            Fall     16.877316
# 1            NaN              NaN            Fall     14.035590
# 2           Fall             71.0            Fall     16.648696
# 3           Fall             71.0          Summer     18.292347
# 4         Summer              NaN             NaN           NaN
# ...          ...              ...             ...           ...
# 3955      Spring             60.0            Fall     16.362460
# 3956         NaN              NaN          Spring     18.764678
# 3957      Spring             68.0          Winter     21.441500
# 3958      Spring             70.0          Winter     12.235895
# 3959         NaN              NaN          Winter           NaN
#
#       Physical-Height  Physical-Weight  ...  total_inactive_duration_min_min  \
# 0                46.0             50.8  ...                              NaN
# 1                48.0             46.0  ...                              NaN
# 2                56.5             75.6  ...                              NaN
# 3                56.0             81.6  ...                         0.083333
# 4                 NaN              NaN  ...                              NaN
# ...               ...              ...  ...                              ...
# 3955             59.5             82.4  ...                              NaN
# 3956             53.5             76.4  ...                              NaN
# 3957             60.0            109.8  ...                        89.000000
# 3958             70.7             87.0  ...                        15.333333
# 3959              NaN              NaN  ...                              NaN
#
#       total_inactive_duration_min_max  daily_wear_time_min_mean  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                          138.000000                100.071759
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 3955                              NaN                       NaN
# 3956                              NaN                       NaN
# 3957                       638.833333               1356.996667
# 3958                       695.833333                525.013889
# 3959                              NaN                       NaN
#
#       daily_wear_time_min_std daily_wear_time_min_min  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                  152.028051                0.250000
# 4                         NaN                     NaN
# ...                       ...                     ...
# 3955                      NaN                     NaN
# 3956                      NaN                     NaN
# 3957               254.763046              403.583333
# 3958               423.576140               15.333333
# 3959                      NaN                     NaN
#
#       daily_wear_time_min_max  pct_inactive_day_mean  pct_inactive_day_std  \
# 0                         NaN                    NaN                   NaN
# 1                         NaN                    NaN                   NaN
# 2                         NaN                    NaN                   NaN
# 3                  648.166667              55.349947             34.038769
# 4                         NaN                    NaN                   NaN
# ...                       ...                    ...                   ...
# 3955                      NaN                    NaN                   NaN
# 3956                      NaN                    NaN                   NaN
# 3957              1440.000000              21.975680             17.158864
# 3958              1440.000000              59.657624             36.489241
# 3959                      NaN                    NaN                   NaN
#
#      pct_inactive_day_min  pct_inactive_day_max
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                2.127660            100.000000
# 4                     NaN                   NaN
# ...                   ...                   ...
# 3955                  NaN                   NaN
# 3956                  NaN                   NaN
# 3957             8.986020             99.649032
# 3958             7.888012            100.000000
# 3959                  NaN                   NaN
#
# [3960 rows x 202 columns]

# %%
data
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 3     00115b9f                    Winter                9                0
# 4     0016bb22                    Spring               18                1
# ...        ...                       ...              ...              ...
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3957  ffcd4dbd                      Fall               11                0
# 3958  ffed1dd5                    Spring               13                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# 0         Winter             51.0            Fall     16.877316
# 1            NaN              NaN            Fall     14.035590
# 2           Fall             71.0            Fall     16.648696
# 3           Fall             71.0          Summer     18.292347
# 4         Summer              NaN             NaN           NaN
# ...          ...              ...             ...           ...
# 3955      Spring             60.0            Fall     16.362460
# 3956         NaN              NaN          Spring     18.764678
# 3957      Spring             68.0          Winter     21.441500
# 3958      Spring             70.0          Winter     12.235895
# 3959         NaN              NaN          Winter           NaN
#
#       Physical-Height  Physical-Weight  ...  total_inactive_duration_min_min  \
# 0                46.0             50.8  ...                              NaN
# 1                48.0             46.0  ...                              NaN
# 2                56.5             75.6  ...                              NaN
# 3                56.0             81.6  ...                         0.083333
# 4                 NaN              NaN  ...                              NaN
# ...               ...              ...  ...                              ...
# 3955             59.5             82.4  ...                              NaN
# 3956             53.5             76.4  ...                              NaN
# 3957             60.0            109.8  ...                        89.000000
# 3958             70.7             87.0  ...                        15.333333
# 3959              NaN              NaN  ...                              NaN
#
#       total_inactive_duration_min_max  daily_wear_time_min_mean  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                          138.000000                100.071759
# 4                                 NaN                       NaN
# ...                               ...                       ...
# 3955                              NaN                       NaN
# 3956                              NaN                       NaN
# 3957                       638.833333               1356.996667
# 3958                       695.833333                525.013889
# 3959                              NaN                       NaN
#
#       daily_wear_time_min_std daily_wear_time_min_min  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 3                  152.028051                0.250000
# 4                         NaN                     NaN
# ...                       ...                     ...
# 3955                      NaN                     NaN
# 3956                      NaN                     NaN
# 3957               254.763046              403.583333
# 3958               423.576140               15.333333
# 3959                      NaN                     NaN
#
#       daily_wear_time_min_max  pct_inactive_day_mean  pct_inactive_day_std  \
# 0                         NaN                    NaN                   NaN
# 1                         NaN                    NaN                   NaN
# 2                         NaN                    NaN                   NaN
# 3                  648.166667              55.349947             34.038769
# 4                         NaN                    NaN                   NaN
# ...                       ...                    ...                   ...
# 3955                      NaN                    NaN                   NaN
# 3956                      NaN                    NaN                   NaN
# 3957              1440.000000              21.975680             17.158864
# 3958              1440.000000              59.657624             36.489241
# 3959                      NaN                    NaN                   NaN
#
#      pct_inactive_day_min  pct_inactive_day_max
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                2.127660            100.000000
# 4                     NaN                   NaN
# ...                   ...                   ...
# 3955                  NaN                   NaN
# 3956                  NaN                   NaN
# 3957             8.986020             99.649032
# 3958             7.888012            100.000000
# 3959                  NaN                   NaN
#
# [3960 rows x 202 columns]

# %%
final_data[final_data["pct_inactive_day_min"].isnull()]
# Out:
#             id Basic_Demos-Enroll_Season  Basic_Demos-Age  Basic_Demos-Sex  \
# 0     00008ff9                      Fall                5                0
# 1     000fd460                    Summer                9                0
# 2     00105258                    Summer               10                1
# 4     0016bb22                    Spring               18                1
# 6     0038ba98                      Fall               10                0
# ...        ...                       ...              ...              ...
# 3953  ff6c2bb8                      Fall                8                0
# 3954  ff759544                    Summer                7                1
# 3955  ff8a2de4                      Fall               13                0
# 3956  ffa9794a                    Winter               10                0
# 3959  ffef538e                    Spring               11                0
#
#      CGAS-Season  CGAS-CGAS_Score Physical-Season  Physical-BMI  \
# 0         Winter             51.0            Fall     16.877316
# 1            NaN              NaN            Fall     14.035590
# 2           Fall             71.0            Fall     16.648696
# 4         Summer              NaN             NaN           NaN
# 6            NaN              NaN            Fall     19.660760
# ...          ...              ...             ...           ...
# 3953         NaN              NaN            Fall     17.139810
# 3954         NaN              NaN          Summer     13.927006
# 3955      Spring             60.0            Fall     16.362460
# 3956         NaN              NaN          Spring     18.764678
# 3959         NaN              NaN          Winter           NaN
#
#       Physical-Height  Physical-Weight  ...  total_inactive_duration_min_min  \
# 0                46.0             50.8  ...                              NaN
# 1                48.0             46.0  ...                              NaN
# 2                56.5             75.6  ...                              NaN
# 4                 NaN              NaN  ...                              NaN
# 6                55.0             84.6  ...                              NaN
# ...               ...              ...  ...                              ...
# 3953             52.5             67.2  ...                              NaN
# 3954             48.5             46.6  ...                              NaN
# 3955             59.5             82.4  ...                              NaN
# 3956             53.5             76.4  ...                              NaN
# 3959              NaN              NaN  ...                              NaN
#
#       total_inactive_duration_min_max  daily_wear_time_min_mean  \
# 0                                 NaN                       NaN
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 4                                 NaN                       NaN
# 6                                 NaN                       NaN
# ...                               ...                       ...
# 3953                              NaN                       NaN
# 3954                              NaN                       NaN
# 3955                              NaN                       NaN
# 3956                              NaN                       NaN
# 3959                              NaN                       NaN
#
#       daily_wear_time_min_std daily_wear_time_min_min  \
# 0                         NaN                     NaN
# 1                         NaN                     NaN
# 2                         NaN                     NaN
# 4                         NaN                     NaN
# 6                         NaN                     NaN
# ...                       ...                     ...
# 3953                      NaN                     NaN
# 3954                      NaN                     NaN
# 3955                      NaN                     NaN
# 3956                      NaN                     NaN
# 3959                      NaN                     NaN
#
#       daily_wear_time_min_max  pct_inactive_day_mean  pct_inactive_day_std  \
# 0                         NaN                    NaN                   NaN
# 1                         NaN                    NaN                   NaN
# 2                         NaN                    NaN                   NaN
# 4                         NaN                    NaN                   NaN
# 6                         NaN                    NaN                   NaN
# ...                       ...                    ...                   ...
# 3953                      NaN                    NaN                   NaN
# 3954                      NaN                    NaN                   NaN
# 3955                      NaN                    NaN                   NaN
# 3956                      NaN                    NaN                   NaN
# 3959                      NaN                    NaN                   NaN
#
#      pct_inactive_day_min  pct_inactive_day_max
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 4                     NaN                   NaN
# 6                     NaN                   NaN
# ...                   ...                   ...
# 3953                  NaN                   NaN
# 3954                  NaN                   NaN
# 3955                  NaN                   NaN
# 3956                  NaN                   NaN
# 3959                  NaN                   NaN
#
# [2964 rows x 202 columns]

# %%
final_data.to_csv("final_data_train.csv", index= False)
